# %%
import requests
from tqdm.auto import tqdm
#import json

# %%
API_KEY = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjY2NzU4MTU4LCJpYXQiOjE2NjY2NzE3NTcsImp0aSI6ImRlNmY5YWFmNmQyYzQwZjM4MWM4NWE5ZWViNmQxMmM1IiwidXNlcl9pZCI6Nn0.pXBsIfGl-8fYY_XoG6R0oFE2vh7vVHXMw1a4K6_qEq8"
N_PAGE = 10

# %%
import requests
import pandas as pd

# %%
url = "https://www.cjexpress.co.th/branch/all"
res = requests.get(url)
res.json()
# Out:
# [{'code': 790,
#   'province': 12,
#   'branch': 'SCวังตาผิน',
#   'address': 'เลขที่ 69/92 หมู่ที่ 4 ตำบลปลวกแดง อำเภอปลวกแดง จังหวัดระยอง 21140',
#   'tel': '061-3847031',
#   'lat': 12.979881,
#   'lng': 101.194,
#   'card': 0,
#   'emoney': 1},
#  {'code': 379,
#   'province': 11,
#   'branch': 'SP บ้านสวน',
#   'address': 'เลขที่ 99/376 หมู่ที่ 7 ตำบลบ้านสวน อำเภอเมืองชลบุรี จังหวัดชลบุรี 20000',
#   'tel': '064-7957735',
#   'lat': 13.372707,
#   'lng': 101.009758,
#   'card': 0,
#   'emoney': 0},
#  {'code': 675,
#   'province': 1,
#   'branch': 'The rich park พหลโยธิน 59',
#   'address': 'เลขที่ 251/2-6 ถนนพหลโยธิน แขวงอนุสาวรีย์  เขตบางเขน  กรุงเทพมหานคร 10220',
#   'tel': '095-8033410',
#   'lat': 13.882466,
#   'lng': 100.600479,
#   'card': 0,
#   'emoney': 1},
#  {'code': 309,
#   'province': 12,
#   'branch': 'กรอกยายชา',
#   'address': 'เลขที่ 18/8  ถนนกรอกยายชา ตำบลเนินพระ  อำเภอเมืองระยอง  จังหวัดระยอง  21000',
#   'tel': '081-3784872',
#   'lat': 12.679917,
# ...

# %%
with open('data.json', 'w', encoding='utf8') as json_file:
    json.dump(res.json(), json_file, ensure_ascii=False, indent=4)

# %%
df = pd.json_normalize(res.json())

# %%
df = df.drop(['lat','lng','card','emoney'],axis=1)

# %%
df
# Out:
#      code  province                     branch  \
# 0     790        12                 SCวังตาผิน
# 1     379        11                 SP บ้านสวน
# 2     675         1  The rich park พหลโยธิน 59
# 3     309        12                  กรอกยายชา
# 4     915        59                กระทุ่มเเบน
# ..    ...       ...                        ...
# 880   600        47                     ไพศาลี
# 881   501         5                     ไม้ตรา
# 882   390        11                ไร่วนาสินธ์
# 883   517        61                  ไร่สะท้อน
# 884   346        11         ไร่หนึ่ง - หนองขาม
#
#                                                address           tel
# 0    เลขที่ 69/92 หมู่ที่ 4 ตำบลปลวกแดง อำเภอปลวกแด...   061-3847031
# 1    เลขที่ 99/376 หมู่ที่ 7 ตำบลบ้านสวน อำเภอเมือง...   064-7957735
# 2    เลขที่ 251/2-6 ถนนพหลโยธิน แขวงอนุสาวรีย์  เขต...   095-8033410
# 3    เลขที่ 18/8  ถนนกรอกยายชา ตำบลเนินพระ  อำเภอเม...   081-3784872
# ...

# %%
df.to_csv('cjexpress.csv',index=None,encoding='utf-8-sig')

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_raw_id = 90

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_raw_id, file_path='data.json')
# Out:
#   0%|          | 0.00/371k [00:00<?, ?B/s]
# {'id': 192,
#  'msg': 'file data.json create sucessful',
#  'path': 'nuraida/DSI310-15/rawData/data.json',
#  'uploaded': True}
